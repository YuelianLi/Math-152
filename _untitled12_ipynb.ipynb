# %% [markdown]
# <a href="https://colab.research.google.com/github/YuelianLi/Math-152/blob/main/_untitled12_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
print ('1. Yuelian Li')
print ('2. first year from The CAM Master Program')
print ('3. Tensor Analysis')
print ('4. Python, Matlab, C++, LaTeX')
print ('5. Mathematical Programming Class from UCSC')
print ('6. design algorithm, python for machine learning')
print ('7. Can we select own members for group project?')
# Out:
# 1. Yuelian Li
# 2. first year from The CAM Master Program
# 3. Tensor Analysis
# 4. Python, Matlab, C++, LaTeX
# 5. Mathematical Programming Class from UCSC
# 6. design algorithm, python for machine learning
# 7. Can we select own members for group project?

# %%
#2
x=1
list3=[]
for i in range (1,100):
  if i%3 == 0:
    list3.append(i)
list5=[]
for j in range (1,100):
  if j%5 == 0:
    list5.append(j)
list15=[15, 30, 45, 60, 75, 90]
while (x<101):
  if x in list15:
    print("fizzbuzz")
  elif x in list5:
    print("buzz")
  elif x in list3:
    print("fizz")
  else:
    print(x)
  x=x+1
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# 100

# %%
"""
Egyptian algorithm
"""

def egyptian_multiplication(a, n):
    """
    returns the product a * n

    assume n is a nonegative integer
    """
    def isodd(n):
        """
        returns True if n is odd
        """
        return n & 0x1 == 1

    if n == 1:
        return a
    if n == 0:
        return 0

    if isodd(n):
        return egyptian_multiplication(a + a, n // 2) + a
    else:
        return egyptian_multiplication(a + a, n // 2)




def power(a, n):
    """
    computes the power a ** n

    assume n is a nonegative integer
    """
    x=0 # this is needed to start while loop
    y=a
    while (x<n//2): #we do n/2 because we are computing a^n in terms of a^2
      z=egyptian_multiplication(a,a) #this is a^2
      print(z)
      y=y*z
      x=x+1
    if (n%2 == 0):
      return y/a #our loop computes a^2 n//2 amount of times but it does not
    else:        #account for odd or even. So, we make a correction by dividing
      return y   #or leaving our result the same based on if its odd or even

if __name__ == '__main__':
    # this code runs when executed as a script
    for a in [1,2,3]:
        for n in [1,2,5,10]:
            print("{} * {} = {}".format(a, n, egyptian_multiplication(a,n)))
    print(power(27,0))
    for i in range (1,6):
      for j in range (1,6):
        print("{}^{} = {}".format(i,j,power(i,j)))
# Out:
# 1 * 1 = 1
# 1 * 2 = 2
# 1 * 5 = 5
# 1 * 10 = 10
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 5 = 10
# 2 * 10 = 20
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 5 = 15
# 3 * 10 = 30
# 1.0
# 1^1 = 1
# 1
# 1^2 = 1.0
# 1
# 1^3 = 1
# 1
# 1
# 1^4 = 1.0
# 1
# 1
# 1^5 = 1
# 2^1 = 2
# 4
# 2^2 = 4.0
# 4
# 2^3 = 8
# 4
# 4
# 2^4 = 16.0
# 4
# 4
# 2^5 = 32
# 3^1 = 3
# 9
# 3^2 = 9.0
# 9
# 3^3 = 27
# 9
# 9
# 3^4 = 81.0
# 9
# 9
# 3^5 = 243
# 4^1 = 4
# 16
# 4^2 = 16.0
# 16
# 4^3 = 64
# 16
# 16
# 4^4 = 256.0
# 16
# 16
# 4^5 = 1024
# 5^1 = 5
# 25
# 5^2 = 25.0
# 25
# 5^3 = 125
# 25
# 25
# 5^4 = 625.0
# 25
# 25
# 5^5 = 3125

# %%
"""
fibonacci

functions to compute fibonacci numbers

Complete problems 2 and 3 in this file.
"""

import time # to compute runtimes
import numpy
#import egyptian.py
from tqdm import tqdm # progress bar

def egyptian_multiplication(a, n): # we must use this function for problem 3
    """
    returns the product a * n

    assume n is a nonegative integer
    """
    def isodd(n):
        """
        returns True if n is odd
        """
        return n & 0x1 == 1

    if n == 1:
        return a
    if n == 0:
        return 0

    if isodd(n):
        return egyptian_multiplication(a + a, n // 2) + a
    else:
        return egyptian_multiplication(a + a, n // 2)

# Question 2
def fibonacci_recursive(n):
    if n==1:
      return 1
    if n==0:
      return 0
    return fibonacci_recursive(n-1)+fibonacci_recursive(n-2)


# Question 2
def fibonacci_iter(n):
    if n==0:
      return 0
    if n==1:
      return 1
    a=0
    b=1
    for o in range(n-1):
      a1=a
      a=b
      b=a1+b
    return b

# Question 3
def fibonacci_power(n):
  A=numpy.array([[1,1],[1,0]])
  B=numpy.array([1,1],[1,0])
  for i in range (n-1):
    alpha = egyptian_multiplication(A[0][0],B[0][0])+egyptian_multiplication(A[0][1],B[1][0])
    beta = egyptian_multiplication(A[0][0],B[0][1])+egyptian_multiplication(A[0][1],B[1][1])
    ceta = egyptian_multiplication(A[1][0],B[0][0])+egyptian_multiplication(A[1][1],B[1][0])
    delta = egyptian_multiplication(A[1][0],B[0][1])+egyptian_multiplication(A[1][1],B[1][1])
    A=numpy.array([[alpha,beta],[ceta,delta]])




if __name__ == '__main__':
    """
    this section of the code only executes when
    this file is run as a script.
    """
    def get_runtimes(ns, f):
        """
        get runtimes for fibonacci(n)

        e.g.
        trecursive = get_runtimes(range(30), fibonacci_recusive)
        will get the time to compute each fibonacci number up to 29
        using fibonacci_recursive
        """
        ts = []
        for n in tqdm(ns):
            t0 = time.time()
            fn = f(n)
            t1 = time.time()
            ts.append(t1 - t0)

        return ts


    nrecursive = range(35)
    trecursive = get_runtimes(nrecursive, fibonacci_recursive)

    niter = range(10000)
    titer = get_runtimes(niter, fibonacci_iter)

    npower = range(10000)
    tpower = get_runtimes(npower, fibonacci_power)

    ## write your code for problem 4 below...
